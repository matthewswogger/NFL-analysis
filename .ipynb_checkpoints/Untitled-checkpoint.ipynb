# %%
import pandas as pd
import numpy as np
import seaborn as ss
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
df_temp = pd.read_csv('nflplaybyplay2015.csv')
# Out:
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df_temp[['Date','GameID','Drive','qtr','down','TimeSecs','yrdline100','ydstogo',\
                                                      'Touchdown','ExPointResult','TwoPointConv','InterceptionThrown']]

# %%
df['offensiveTeam'] = df_temp.posteam
df['DefensiveTeam'] = df_temp.DefensiveTeam
df['desc'] = df_temp.desc
df.down.fillna(0, inplace=True)
df.yrdline100.fillna(0, inplace=True)
df.TimeSecs.fillna(0, inplace=True)
df.ExPointResult.fillna('regular_play', inplace=True)
df.TwoPointConv.fillna('regular_play', inplace=True)
# Out:
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
X = df[['Drive','qtr','down','TimeSecs','yrdline100','ydstogo','Touchdown',\
                                                                'ExPointResult','TwoPointConv','InterceptionThrown']]

# %%
X.ExPointResult[X.ExPointResult == 'regular_play'] = 0
X.ExPointResult[X.ExPointResult == 'Made'] = 1
X.ExPointResult[X.ExPointResult == 'Missed'] = 2
X.ExPointResult[X.ExPointResult == 'Aborted'] = 3
# X.ExPointResult = X.ExPointResult.astype('float')

X.TwoPointConv[X.TwoPointConv == 'regular_play'] = 0
X.TwoPointConv[X.TwoPointConv == 'Success'] = 1
X.TwoPointConv[X.TwoPointConv == 'Failure'] = 2
# X.TwoPointConv = X.TwoPointConv.astype('float')
# Out:
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:4485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kmeans = KMeans(n_clusters=32)
kmeans.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=32, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
assigned_cluster = kmeans.transform(X).argmin(axis=1)
df['cluster_assignment'] = pd.Series(assigned_cluster)
# Out:
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
def split_into_teams_offense(df):
    teams = df.offensiveTeam.unique()
    return [df[df.offensiveTeam == team] for team in teams]

def split_into_teams_defense(df):
    teams = df.DefensiveTeam.unique()
    return [df[df.DefensiveTeam == team] for team in teams]

# %%
df_den_o = df[df.offensiveTeam == 'DEN']

# %%
df_den_o.cluster_assignment.unique()
# Out:
# array([22,  3, 20, 26,  7, 14, 31,  1, 28, 17,  9,  4, 23, 29, 11,  2, 16,
#        24,  8, 18, 13, 27, 30,  0,  6, 15, 12, 21,  5, 10, 25, 19])

# %%
df_den_o.groupby('cluster_assignment').count()
# Out:
#                     Date  GameID  Drive  qtr  down  TimeSecs  yrdline100  \
# cluster_assignment
# 0                     41      41     41   41    41        41          41
# 1                     21      21     21   21    21        21          21
# 2                     47      47     47   47    47        47          47
# 3                     37      37     37   37    37        37          37
# 4                     34      34     34   34    34        34          34
# 5                     45      45     45   45    45        45          45
# 6                     34      34     34   34    34        34          34
# 7                     36      36     36   36    36        36          36
# 8                     39      39     39   39    39        39          39
# 9                     45      45     45   45    45        45          45
# 10                    67      67     67   67    67        67          67
# 11                    36      36     36   36    36        36          36
# 12                    46      46     46   46    46        46          46
# 13                    50      50     50   50    50        50          50
# 14                    39      39     39   39    39        39          39
# 15                    43      43     43   43    43        43          43
# 16                    55      55     55   55    55        55          55
# 17                    38      38     38   38    38        38          38
# 18                    51      51     51   51    51        51          51
# 19                    19      19     19   19    19        19          19
# 20                    35      35     35   35    35        35          35
# 21                    36      36     36   36    36        36          36
# 22                    28      28     28   28    28        28          28
# 23                    51      51     51   51    51        51          51
# 24                    48      48     48   48    48        48          48
# 25                    41      41     41   41    41        41          41
# 26                    58      58     58   58    58        58          58
# 27                    38      38     38   38    38        38          38
# 28                    42      42     42   42    42        42          42
# 29                    75      75     75   75    75        75          75
# 30                    37      37     37   37    37        37          37
# 31                    38      38     38   38    38        38          38
#
#                     ydstogo  Touchdown  ExPointResult  TwoPointConv  \
# cluster_assignment
# 0                        41         41             41            41
# 1                        21         21             21            21
# 2                        47         47             47            47
# 3                        37         37             37            37
# 4                        34         34             34            34
# 5                        45         45             45            45
# 6                        34         34             34            34
# 7                        36         36             36            36
# 8                        39         39             39            39
# 9                        45         45             45            45
# 10                       67         67             67            67
# 11                       36         36             36            36
# 12                       46         46             46            46
# 13                       50         50             50            50
# 14                       39         39             39            39
# 15                       43         43             43            43
# 16                       55         55             55            55
# 17                       38         38             38            38
# 18                       51         51             51            51
# 19                       19         19             19            19
# 20                       35         35             35            35
# 21                       36         36             36            36
# 22                       28         28             28            28
# 23                       51         51             51            51
# 24                       48         48             48            48
# 25                       41         41             41            41
# 26                       58         58             58            58
# 27                       38         38             38            38
# 28                       42         42             42            42
# 29                       75         75             75            75
# 30                       37         37             37            37
# 31                       38         38             38            38
#
#                     InterceptionThrown  offensiveTeam  DefensiveTeam  desc
# cluster_assignment
# 0                                   41             41             41    41
# 1                                   21             21             21    21
# 2                                   47             47             47    47
# 3                                   37             37             37    37
# 4                                   34             34             34    34
# 5                                   45             45             45    45
# 6                                   34             34             34    34
# 7                                   36             36             36    36
# 8                                   39             39             39    39
# 9                                   45             45             45    45
# 10                                  67             67             67    67
# 11                                  36             36             36    36
# 12                                  46             46             46    46
# 13                                  50             50             50    50
# 14                                  39             39             39    39
# 15                                  43             43             43    43
# 16                                  55             55             55    55
# 17                                  38             38             38    38
# 18                                  51             51             51    51
# 19                                  19             19             19    19
# 20                                  35             35             35    35
# 21                                  36             36             36    36
# 22                                  28             28             28    28
# 23                                  51             51             51    51
# 24                                  48             48             48    48
# 25                                  41             41             41    41
# 26                                  58             58             58    58
# 27                                  38             38             38    38
# 28                                  42             42             42    42
# 29                                  75             75             75    75
# 30                                  37             37             37    37
# 31                                  38             38             38    38
